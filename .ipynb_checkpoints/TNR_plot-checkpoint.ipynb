# %%
import torch

torch.set_default_tensor_type(torch.cuda.DoubleTensor)
torch.cuda.set_device(1)

# %% [markdown]
# # TNR Evolution

# %%
filename='data/tnr_X24'

params,options=torch.load(filename+'_options.pkl')

print(params)
print(options)

layers,Ts,logTotals=torch.load(filename+'_tensors.pkl')
# Out:
# {'beta': 0.44068679350977147, 'h': 0}
# {'nLayers': 20, 'tnr_max_dim_TRG': 24, 'tnr_max_dim_TNR': 12, 'tnr_max_nIter': 200, 'tnr_threshold_TTdiff': 1e-07, 'mcf_enabled': True, 'mcf_eps': 1e-06, 'mcf_max_iter': 200}

# %%
from ScalingDimensions import show_effective_rank,show_diff,show_scaling_dimensions,show_asymmetry

reference_scaling_dimensions=[0.125,1,1.125,2,2.125,3,3.125,4,4.125,5,5.125,6,6.125]
reference_center_charge=.5

show_effective_rank(Ts)
show_diff(Ts,stride=1)
curve=show_scaling_dimensions(Ts,loop_length=2,num_scaling_dims=128,volume_scaling=4,is_HOTRG=False,reference_scaling_dimensions=reference_scaling_dimensions,reference_center_charge=reference_center_charge)
#show_asymmetry(Ts);
# Out:
# ...
#   0%|          | 0/21 [00:00<?, ?it/s]
