# %%
import sys,importlib
import IsingSolutions
importlib.reload(IsingSolutions)
from IsingSolutions import *
import numpy as np
import matplotlib.pyplot as plt

# %%
ising2d.display()
# Out:
# critical_beta 0.44068679350977147

# %%
refbeta=np.linspace(.3,.6,100)
logZ=ising2d.logZ(refbeta)
ddlogZ=np.gradient(np.gradient(logZ,refbeta),refbeta)

plt.plot(refbeta,ddlogZ)
plt.plot(refbeta,ising2d.ddlogZ(refbeta))
